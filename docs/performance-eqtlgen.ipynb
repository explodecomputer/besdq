# %% [markdown]
# # BESDQ Performance — eQTLGen
#
# Benchmarks against the eQTLGen whole-blood cis-eQTL dataset (~16k traits).
# Run this notebook locally (dataset is too large for CI) then commit `docs/performance-eqtlgen.md`:
#
# ```bash
# jupyter nbconvert --to markdown --execute --output performance-eqtlgen.md --output-dir docs/ docs/performance-eqtlgen.ipynb
# ```

# %% [markdown]
# **TODO**: migrate relevant cells from `notes.ipynb` (eQTLgen sections) into this notebook.

# %%
# %%bash
# smr="../data/smr"
# myeqtlbig="../data/eqtlgen-sparse"
# # Create the eqtlgen dataset
# # Note, takes a while
# wget https://download.gcc.rug.nl/downloads/eqtlgen/cis-eqtl/SMR_formatted/cis-eQTL-SMR_20191212.tar.gz --no-check-certificate
# tar xzvf cis-eQTL-SMR_20191212.tar.gz
# gunzip cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense*
# ${smr} --beqtl-summary cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense --make-besd --out ${myeqtlbig}

# %% [markdown]
# ```bash
# smr="../data/smr"
# myeqtlbig="../data/eqtlgen-sparse"
# # Use SMR
#
# # This takes too long to run?!
# time $smr \
#     --beqtl-summary $myeqtlbig \
#     --query 5e-5 \
#     --snp-chr 1 \
#     --from-snp-kb 100 \
#     --to-snp-kb 2000 \
#     --probe-chr 1 \
#     --from-probe-kb 1000 \
#     --to-probe-kb 2000 \
#     --out results/myquery_smr
# ```

# %%
# %%bash
#
# # This big query actually runs now even without the index
# myeqtlbig="../data/eqtlgen-sparse"
# time besdq \
#     --besd $myeqtlbig \
#     --query 5e-4 \
#     --snp-chr 1 \
#     --from-snp-kb 100 \
#     --to-snp-kb 2000 \
#     --probe-chr 1 \
#     --from-probe-kb 1000 \
#     --to-probe-kb 2000 \
#     --out results/myquery

# %%
# %%bash
#
# myeqtlbig="../data/eqtlgen-sparse"
#
# # Use BESD-index format with besdq
# rm -rf $myeqtlbig.db
# besdq --besd $myeqtlbig --build-db $myeqtlbig.db --n-mode vector

# %%
# %%bash
#
# myeqtlbig="../data/eqtlgen-sparse"
# besdq --db ${myeqtlbig}.db --info

# %%
# %%bash
#
# # This big query actually runs now even without the index
# myeqtlbig="../data/eqtlgen-sparse"
#
# time besdq \
#     --besd-index ${myeqtlbig}.db \
#     --query 5e-4 \
#     --snp-chr 1 \
#     --from-snp-kb 100 \
#     --to-snp-kb 2000 \
#     --probe-chr 1 \
#     --from-probe-kb 1000 \
#     --to-probe-kb 2000 \
#     --out results/myquery
